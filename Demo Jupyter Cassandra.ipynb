# %% [markdown]
# ### Configuration

# %% [markdown]
# #### Modules

# %%
# UI

# Interactive
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
from ipywidgets import Button, HBox, VBox
import ipywidgets as widgets

# Tables
import pandas

# Database
from cassandra.cluster import Cluster

# Plot
# %matplotlib notebook
import matplotlib.pyplot as plt

# Math
import numpy as np

# %% [markdown]
# ### Database conection

# %%
user = ''
password = ''
ip = ''

def setUser(user):
    user = user
    
def setPassword(password):
    password = password

def setIp(ip):
    ip = [ip]

# %% [markdown]
# ----------------------------------------------------

# %%
queries = ['Visitors', 'Users', 'Sells', 'Shared', 'Show trendy', 'Export to Excel']
items = [Button(description=w) for w in queries]

def on_button_clicked(b):
    out.clear_output()
    with out:
        print("Button clicked.")
    
items[0].on_click(on_button_clicked)
items[1].on_click(print_table)
items[2].on_click(print_table)
items[3].on_click(print_table)

left_box = VBox([items[0], items[1]])
center_box = VBox([items[2], items[3]])
right_box = VBox([items[4], items[5]])
# HBox([left_box, right_box])
buttons = HBox([left_box, center_box, right_box])

# %% [markdown]
# ------------------------

# %%
# np.random.seed(100)
#credit_card = {} #pandas.DataFrame(np.random.randint(10, size=(5,5)), columns=list('ABCDE'))

def calculate_table(seed):
    np.random.seed(seed)
    global table 
    table = pandas.DataFrame(np.random.randint(10, size=(5,5)), columns=list('ABCDE')) 
    
def print_table(button):
    seed = {
        'Users': 100,
        'Sells': 200,
        'Shared': 300
    }[button.description]
    out.clear_output()
    calculate_table(seed)
    global table
    with out:
        print(button.description)
        print(table)

# %%
date_picker_start = widgets.DatePicker(description='Start date', disabled=False)
date_picker_end = widgets.DatePicker(description='End date', disabled=False)
date_pickers = widgets.HBox([date_picker_start,date_picker_end])
out = widgets.Output(layout={'border': '1px solid grey'})

# %% [markdown]
# # Dashboard
# Choose the date range and check the desired KPI using the button interface

# %%
widgets.VBox([date_pickers, buttons, out])
# Out:
# VkJveChjaGlsZHJlbj0oSEJveChjaGlsZHJlbj0oRGF0ZVBpY2tlcih2YWx1ZT1Ob25lLCBkZXNjcmlwdGlvbj11J1N0YXJ0IGRhdGUnKSwgRGF0ZVBpY2tlcih2YWx1ZT1Ob25lLCBkZXNjcmnigKY=

# %%
x = np.linspace(0,10)
line, = plt.plot(x, np.sin(x), '--', linewidth=2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import plotly.plotly as py
import plotly.figure_factory as ff
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-70-1618821b0e08> in <module>()
# ----> 1 import plotly.plotly as py
#       2 import plotly.figure_factory as ff
#
# ImportError: No module named plotly.plotly
